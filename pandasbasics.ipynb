# %%
import numpy as np
import pandas as pd

# %%
dict={'name':['ram','shyam','rohan','mohan'],
     'marks':[92,3,4,56],
     'city':['varanasi','guwahati','mirzapur','lanka']}

# %%
df=pd.DataFrame(dict)
df
# Out:
#     name  marks      city
# 0    ram     92  varanasi
# 1  shyam      3  guwahati
# 2  rohan      4  mirzapur
# 3  mohan     56     lanka

# %%
df.to_csv('friend.csv')
df
# Out:
#     name  marks      city
# 0    ram     92  varanasi
# 1  shyam      3  guwahati
# 2  rohan      4  mirzapur
# 3  mohan     56     lanka

# %%
df.to_csv('friendwithnoindex.csv',index=False)
df#index wala column nhi show krega
# Out:
#     name  marks      city
# 0    ram     92  varanasi
# 1  shyam      3  guwahati
# 2  rohan      4  mirzapur
# 3  mohan     56     lanka

# %%
df.head(2)
df.tail(3)#it means last ke 3 row dikhayega
# Out:
#     name  marks      city
# 1  shyam      3  guwahati
# 2  rohan      4  mirzapur
# 3  mohan     56     lanka

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   38.750000
# std    43.277207
# min     3.000000
# 25%     3.750000
# 50%    30.000000
# 75%    65.000000
# max    92.000000

# %%
ut=pd.read_csv('vgsales.csv')
ut
# Out:
#        Unnamed: 0   Rank                                              Name  \
# 0               0      1                                           utkarsh
# 1               1      2                                 Super Mario Bros.
# 2               2      3                                    Mario Kart Wii
# 3               3      4                                 Wii Sports Resort
# 4               4      5                          Pokemon Red/Pokemon Blue
# ...           ...    ...                                               ...
# 16593       16593  16596                Woody Woodpecker in Crazy Castle 5
# 16594       16594  16597                     Men in Black II: Alien Escape
# 16595       16595  16598  SCORE International Baja 1000: The Official Game
# 16596       16596  16599                                        Know How 2
# 16597       16597  16600                                  Spirits & Spells
#
# ...

# %%
ut['Name'][0]='utkarsh'##it will change first name to utkarsh
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_38180\382169219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ut['Name'][0]='utkarsh'

# %%
ut.to_csv('vgsales.csv')## csv file me pahla name replace ho gya
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ut.to_csv('vgsales.csv')## csv file me pahla name replace ho gya
#
# NameError: name 'ut' is not defined

# %%
# ut.index=[] isse index ka naam xhange kr sakte hai parameter medatkr

# %%
ser=pd.Series(np.random.rand(23))

# %%
new=pd.DataFrame(np.random.rand(334,5))
new.head()
# Out:
#           0         1         2         3         4
# 0  0.820710  0.925265  0.409042  0.162901  0.280143
# 1  0.414230  0.357326  0.154225  0.975185  0.783756
# 2  0.062459  0.887353  0.008522  0.411064  0.120948
# 3  0.460191  0.822488  0.204708  0.605619  0.984710
# 4  0.631332  0.454831  0.179219  0.781959  0.018590

# %%
new[0][0]=4
# new.index  vertical column
#new.column it willl provide horizontal row of dataframe
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
new.to_numpy()
# Out:
# array([[4.        , 0.18139922, 0.2808369 , 0.10108841, 0.10045296],
#        [0.45085432, 0.50134538, 0.52289472, 0.34286825, 0.71289563],
#        [0.82639122, 0.48206097, 0.22600525, 0.23583082, 0.60443398],
#        ...,
#        [0.39141172, 0.02354319, 0.94172205, 0.64948036, 0.46396628],
#        [0.80657125, 0.17796823, 0.16134153, 0.07257068, 0.46189311],
#        [0.51536469, 0.30684378, 0.90964807, 0.93944962, 0.93138626]])

# %%
new.T # transpose
# Out:
#         0         1         2         3         4         5         6    \
# 0  4.000000  0.450854  0.826391  0.463915  0.909036  0.840129  0.343991
# 1  0.181399  0.501345  0.482061  0.402979  0.598258  0.101945  0.916077
# 2  0.280837  0.522895  0.226005  0.527460  0.475628  0.134926  0.450246
# 3  0.101088  0.342868  0.235831  0.058213  0.954611  0.100691  0.471194
# 4  0.100453  0.712896  0.604434  0.374470  0.376129  0.808500  0.482080
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.954618  0.979385  0.673741  ...  0.035578  0.524607  0.083339  0.867546
# 1  0.217165  0.526649  0.917424  ...  0.930584  0.437544  0.602929  0.276288
# 2  0.719291  0.891387  0.522873  ...  0.855502  0.794282  0.499786  0.703105
# 3  0.101958  0.206130  0.910301  ...  0.502471  0.774044  0.750928  0.390980
# 4  0.569908  0.977333  0.051045  ...  0.063068  0.033207  0.730272  0.729028
#
#         328       329       330       331       332       333
# ...

# %%
new.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3         4
# 333  0.515365  0.306844  0.909648  0.939450  0.931386
# 332  0.806571  0.177968  0.161342  0.072571  0.461893
# 331  0.391412  0.023543  0.941722  0.649480  0.463966
# 330  0.559953  0.891679  0.139868  0.434723  0.917082
# 329  0.079785  0.138147  0.207960  0.616739  0.070163
# ..        ...       ...       ...       ...       ...
# 4    0.909036  0.598258  0.475628  0.954611  0.376129
# 3    0.463915  0.402979  0.527460  0.058213  0.374470
# 2    0.826391  0.482061  0.226005  0.235831  0.604434
# 1    0.450854  0.501345  0.522895  0.342868  0.712896
# 0    4.000000  0.181399  0.280837  0.101088  0.100453
#
# [334 rows x 5 columns]

# %%
new2=new.copy() #it will copy new without any change in new file

# %%
new[0][0]=654
new.head(2)
# Out:
#            0         1         2         3         4
# 0  654.00000  0.925265  0.409042  0.162901  0.280143
# 1    0.41423  0.357326  0.154225  0.975185  0.783756

# %%
new.columns=list('abcde') # column ka naam change kr dega
new.head()
# Out:
#             a         b         c         d         e
# 0  654.000000  0.925265  0.409042  0.162901  0.280143
# 1    0.414230  0.357326  0.154225  0.975185  0.783756
# 2    0.062459  0.887353  0.008522  0.411064  0.120948
# 3    0.460191  0.822488  0.204708  0.605619  0.984710
# 4    0.631332  0.454831  0.179219  0.781959  0.018590

# %%
 new.drop(['e'],axis=1) 
    ## it will drop eth wala column
    # drop(index=[],columns=[]) isse apne hisab se column and row drop kr sakte hai
# Out:
#               a         b         c         d
# 0    654.000000  0.925265  0.409042  0.162901
# 1      0.414230  0.357326  0.154225  0.975185
# 2      0.062459  0.887353  0.008522  0.411064
# 3      0.460191  0.822488  0.204708  0.605619
# 4      0.631332  0.454831  0.179219  0.781959
# ..          ...       ...       ...       ...
# 329    0.169955  0.214004  0.039709  0.707061
# 330    0.818667  0.988653  0.366685  0.934627
# 331    0.563158  0.763944  0.133432  0.680540
# 332    0.866182  0.442318  0.346332  0.075014
# 333    0.685375  0.422269  0.208834  0.318225
#
# [334 rows x 4 columns]

# %%
new.loc[[1,3],['c','d']]## issee jo row and column chhahe print kara sakte hai
##doesnot change the data frame
# Out:
#           c         d
# 1  0.522895  0.342868
# 3  0.527460  0.058213

# %%
new.loc[[1,2],:]## means all the column
# Out:
#           a         b         c         d         e
# 1  0.450854  0.501345  0.522895  0.342868  0.712896
# 2  0.826391  0.482061  0.226005  0.235831  0.604434

# %%
new.loc[(new['a']<0.3)&(new['c']>0.1)]#isi condition ke according rows dikhayea
# Out:
#             a         b         c         d         e
# 12   0.007800  0.178509  0.436394  0.320999  0.733306
# 13   0.150624  0.653888  0.460637  0.168533  0.719734
# 14   0.016062  0.744610  0.650926  0.948484  0.471445
# 38   0.109868  0.321363  0.905916  0.973065  0.362301
# 41   0.236297  0.188296  0.305796  0.756141  0.695480
# ..        ...       ...       ...       ...       ...
# 315  0.074657  0.995699  0.609371  0.569665  0.554966
# 321  0.049116  0.548515  0.170563  0.407594  0.642374
# 324  0.035578  0.930584  0.855502  0.502471  0.063068
# 326  0.083339  0.602929  0.499786  0.750928  0.730272
# 329  0.079785  0.138147  0.207960  0.616739  0.070163
#
# [77 rows x 5 columns]

# %%
new.iloc[0,4]#it is used with indexing 
#agar row ke indexing se calll krna hai to loc use krte hai
#we can use indexing in iloc even when the indexing is done in differnt format
# Out:
# 0.10045295996120263

# %%
new.iloc[[0,5],[1,3]]
# Out:
#           b         d
# 0  0.181399  0.101088
# 5  0.101945  0.100691

# %%
# original ko modify krne ke liye inplace =True likhna hai

# %%
new.reset_index(drop=True,inplace=True) #isse fir se restore ho jata hai

# %%
new
# Out:
#               a         b         c         d         e
# 0    654.000000  0.181399  0.280837  0.101088  0.100453
# 1      0.450854  0.501345  0.522895  0.342868  0.712896
# 2      0.826391  0.482061  0.226005  0.235831  0.604434
# 3      0.463915  0.402979  0.527460  0.058213  0.374470
# 4      0.909036  0.598258  0.475628  0.954611  0.376129
# ..          ...       ...       ...       ...       ...
# 329    0.079785  0.138147  0.207960  0.616739  0.070163
# 330    0.559953  0.891679  0.139868  0.434723  0.917082
# 331    0.391412  0.023543  0.941722  0.649480  0.463966
# 332    0.806571  0.177968  0.161342  0.072571  0.461893
# 333    0.515365  0.306844  0.909648  0.939450  0.931386
#
# [334 rows x 5 columns]

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       334 non-null    float64
#  1   b       334 non-null    float64
#  2   c       334 non-null    float64
#  3   d       334 non-null    float64
#  4   e       334 non-null    float64
# dtypes: float64(5)
# memory usage: 13.2 KB

# %%
df=pd.DataFrame(np.random.randint(2,5,size=(3,2)))
df
# Out:
#    0  1
# 0  2  4
# 1  2  3
# 2  3  4

# %%
data=pd.read_excel('ma102.xlsx')
data
# Out:
#      Unnamed: 0  Sl. No.   Roll No.                Name Division Tutorial  \
# 0             0        1  220101001     ABHIDEEP BISHUI      III      T01
# 1             1        2  220101002      ABHISHEK KUMAR      III      T01
# 2             2        3  220101003        ADARSH GUPTA      III      T01
# 3             3        4  220101004     ADARSH MANUPATI      III      T01
# 4             4        1  220101005        ADITYA KUMAR      III      T02
# ..          ...      ...        ...                 ...      ...      ...
# 993         993      885  210121063  VISHAL SINGH MAHAR      Any      T20
# 994         994      886  210122002        AMBIKA SINGH      Any      T20
# 995         995      887  210122013     BANOTHU KARTHIK      Any      T20
# 996         996      888  210122017     DEEPESH KAUSHIK      Any      T20
# 997         997      889  210122030         MOHIT ANAND      Any      T20
#
#     Midsem
# 0        7
# 1       23
# 2       25
# 3        0
# 4       26
# ...

# %%
newdata=data.iloc[:,[0,1,2,3,4,6]]
newdata.to_excel('ma102.xlsx')

# %%
newdata.head(5)
# Out:
#    Sl. No.   Roll No.             Name Division Tutorial Midsem
# 0        1  220101001  ABHIDEEP BISHUI      III      T01      7
# 1        2  220101002   ABHISHEK KUMAR      III      T01     23
# 2        3  220101003     ADARSH GUPTA      III      T01     25
# 3        4  220101004  ADARSH MANUPATI      III      T01      0
# 4        1  220101005     ADITYA KUMAR      III      T02     26

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl. No.   998 non-null    int64
#  1   Roll No.  998 non-null    int64
#  2   Name      998 non-null    object
#  3   Division  998 non-null    object
#  4   Tutorial  998 non-null    object
#  5   Midsem    990 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 46.9+ KB

# %%
newdata['Midsem']=newdata['Midsem'].astype(int)
newdata
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 newdata['Midsem']=newdata['Midsem'].astype(int)
#       2 newdata
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
newdata['Midsem'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 newdata['Midsem'].mean()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
# ...

# %%
data
# Out:
#   Cell In[102], line 1
#     newdata[['Midsem'],axis=0].mean()
#                        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
